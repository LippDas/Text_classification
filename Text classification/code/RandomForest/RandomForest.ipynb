# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score

# %%
df = pd.read_csv('/Users/lippd/Desktop/ML in R/Python/Text classification/data/cars.csv', sep=";")

# %%
labels = np.unique(df['marka_pop'])

# %%
df = df.reindex(np.random.permutation(df.index))

# %%
df_test = df[0:1000].copy()
df_validation = df[1000:2500].copy()
df_training = df[2500:].copy()

# %%
vectorizer = CountVectorizer()

# %%
vectorizer.fit(df_training['marka'])
# Out:
# CountVectorizer()

# %%
x_training = vectorizer.transform(df_training['marka'])

# %%
y_training = df_training['marka']

# %%
list_of_results = []

# %%
for n_estimators in [30, 100, 150, 200]:
    for criterion in ['gini', 'entropy']:
        for min_samples_leaf in [1, 2, 3]:
            for min_samples_split in [2, 3]:
                for max_features in [None, "sqrt", "log2"]:
                    for bootstrap in [True, False]:
                        for oob_score in [True, False]:
                            for warm_start in [True, False]:
                                for class_weight in [None, 'balanced', 'balanced_subsample']:
                                    try:

                                        clf = RandomForestClassifier(n_estimators=n_estimators, criterion=criterion,
                                                                     min_samples_leaf=min_samples_leaf,
                                                                     min_samples_split=min_samples_split,
                                                                     max_features=max_features, bootstrap=bootstrap,
                                                                     oob_score=oob_score, warm_start=warm_start,
                                                                     class_weight=class_weight)
                                        print(
                                            "n_estimators={}, criterion={}, min_samples_leaf={}, min_samples_split={}, max_features={}, bootstrap={},oob_score={}, warm_start={}, class_weight={}".
                                                format(n_estimators, criterion, min_samples_leaf, min_samples_split,
                                                       max_features, bootstrap, oob_score, warm_start, class_weight))
                                        # we fit the model to our training data (ie. we calculate the model parameters)
                                        clf.fit(x_training, y_training)
                                        # Convert the validation narratives to a feature matrix
                                        x_validation = vectorizer.transform(df_validation['marka'])
                                        # Generate predicted codes for our validation narratives
                                        y_validation_pred = clf.predict(x_validation)
                                        # Calculate how accurately these match the true codes
                                        y_validation = df_validation['marka_pop']
                                        val_accuracy = accuracy_score(y_validation, y_validation_pred)
                                        y_training_pred = clf.predict(x_training)
                                        train_accuracy = accuracy_score(y_training, y_training_pred)
                                        f1_score_micro = f1_score(y_validation, y_validation_pred, average='micro')
                                        list_of_results.append(
                                            [n_estimators, criterion, min_samples_leaf, min_samples_split,
                                             max_features, bootstrap, oob_score, warm_start, class_weight,
                                             val_accuracy, train_accuracy, f1_score_micro])
                                    except ValueError:
                                        print(ValueError)
# Out:
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=True, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=True, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=False, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=True, warm_start=True, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=True, warm_start=False, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=False, warm_start=True, class_weight=None
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=None, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=None
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=True, warm_start=False, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=False, warm_start=True, class_weight=None
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=2, max_features=log2, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=True, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=True, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=False, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=True, warm_start=True, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=True, warm_start=False, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=False, warm_start=True, class_weight=None
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=None, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=None
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=None
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=None
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced
# <class 'ValueError'>
# n_estimators=30, criterion=gini, min_samples_leaf=1, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced_subsample
# <class 'ValueError'>
# ...
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced_subsample
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=None
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=None
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=None
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=sqrt, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=True, warm_start=False, class_weight=balanced_subsample
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=True,oob_score=False, warm_start=False, class_weight=balanced_subsample
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=None
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=True, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=False, class_weight=None
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=True, warm_start=False, class_weight=balanced_subsample
# <class 'ValueError'>
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=False, warm_start=True, class_weight=None
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=False, warm_start=True, class_weight=balanced_subsample
# G:\Program Files (x86)\anaconda\lib\site-packages\sklearn\ensemble\_forest.py:586: UserWarning: class_weight presets "balanced" or "balanced_subsample" are not recommended for warm_start if the fitted data differs from the full dataset. In order to use "balanced" weights, use compute_class_weight ("balanced", classes, y). In place of y you can use a large enough sample of the full training set target to properly estimate the class frequency distributions. Pass the resulting weights as the class_weight parameter.
#   warn('class_weight presets "balanced" or '
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=False, warm_start=False, class_weight=None
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced
# n_estimators=200, criterion=entropy, min_samples_leaf=3, min_samples_split=3, max_features=log2, bootstrap=False,oob_score=False, warm_start=False, class_weight=balanced_subsample

# %%
df_to_excel = pd.DataFrame(list_of_results)

# %%
df_to_excel
df_to_excel.to_excel("results_random_forests.xlsx")
